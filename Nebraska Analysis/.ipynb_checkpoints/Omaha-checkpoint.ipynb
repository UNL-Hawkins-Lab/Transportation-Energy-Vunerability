# %%
import geopandas as gpd
import pandas as pd
import pathlib

import matplotlib.pyplot as plt

from cartopy import crs as ccrs

import os
import sys
import subprocess
import datetime
import platform
import datetime

# %%
Omaha = gpd.read_file("BaseMap/omaha_ct_ne_ia.shp")

# %%
Omaha.head()
# Out:
#   STATEFP COUNTYFP TRACTCE AFFGEOID        GEOID  NAME  LSAD  ALAND  AWATER  \
# 0    None     None    None     None  31055006102  None  None    NaN     NaN
# 1    None     None    None     None  31055006400  None  None    NaN     NaN
# 2    None     None    None     None  31055006704  None  None    NaN     NaN
# 3    None     None    None     None  31055006905  None  None    NaN     NaN
# 4    None     None    None     None  31055007002  None  None    NaN     NaN
#
#   STATEFP_2 COUNTYFP_2 TRACTCE_2            AFFGEOID_2      GEOID_2 NAME_2  \
# 0        31        055    006102  1400000US31055006102  31055006102  61.02
# 1        31        055    006400  1400000US31055006400  31055006400     64
# 2        31        055    006704  1400000US31055006704  31055006704  67.04
# 3        31        055    006905  1400000US31055006905  31055006905  69.05
# 4        31        055    007002  1400000US31055007002  31055007002  70.02
#
#   LSAD_2    ALAND_2  AWATER_2  \
# 0     CT  2514773.0       0.0
# 1     CT  2734652.0       0.0
# 2     CT  2145461.0   99304.0
# 3     CT  1692285.0   14361.0
# 4     CT  1720127.0       0.0
#
#                                             geometry
# 0  POLYGON ((-95.97578 41.31006, -95.97578 41.311...
# 1  POLYGON ((-96.02387 41.26328, -96.02387 41.266...
# 2  POLYGON ((-96.08508 41.24870, -96.08356 41.250...
# 3  POLYGON ((-96.06232 41.22337, -96.05886 41.223...
# 4  POLYGON ((-96.00472 41.23060, -95.99513 41.230...

# %%
Omaha.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Exposure

# %%
ex = pd.read_csv('exposure_census.csv', dtype = {"GEOID":str,"GEO_ID":str})
ex.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1  State  Price              AFFGEOID  \
# 0             0           0             0      9  2.229  1400000US09001022000
# 1             1           1             1      9  2.229  1400000US09001042500
# 2             2           2             2      9  2.229  1400000US09001043500
# 3             3           3             3      9  2.229  1400000US09001010700
# 4             4           4             4      9  2.229  1400000US09001021500
#
#          GEOID         fuel       GEO_ID  \
# 0  09001022000  1057.581145  09001022000
# 1  09001042500  1175.059270  09001042500
# 2  09001043500  1108.900146  09001043500
# 3  09001010700   591.341144  09001010700
# 4  09001021500   561.379578  09001021500
#
#                                               NAME  HH_num_total  \
# 0  Census Tract 220, Fairfield County, Connecticut          1020
# 1  Census Tract 425, Fairfield County, Connecticut          1465
# 2  Census Tract 435, Fairfield County, Connecticut           933
# 3  Census Tract 107, Fairfield County, Connecticut          1682
# 4  Census Tract 215, Fairfield County, Connecticut          2094
#
#    median_income  exposure  min_max_ex
# 0        82753.0  0.028487    0.055157
# 1       129821.0  0.020176    0.035431
# 2       104417.0  0.023672    0.043729
# 3        61667.0  0.021374    0.038277
# 4        43357.0  0.028861    0.056045

# %%
ex = ex[['GEOID','fuel','Price','exposure','min_max_ex']]
om_ex = pd.merge(ex,Omaha,left_on='GEOID',right_on='GEOID',how='right')

# %%
om_ex = gpd.GeoDataFrame(om_ex,crs = 4326)
# Out:
# C:\Users\jhawkins17\AppData\Local\Temp\ipykernel_18136\3438186438.py:1: FutureWarning: CRS mismatch between CRS of the passed geometries and 'crs'. Use 'GeoDataFrame.set_crs(crs, allow_override=True)' to overwrite CRS or 'GeoDataFrame.to_crs(crs)' to reproject geometries. CRS mismatch will raise an error in the future versions of GeoPandas.
#   om_ex = gpd.GeoDataFrame(om_ex,crs = 4326)

# %%
import numpy as np

fig, ax = plt.subplots(figsize=(12, 10),dpi=300)

font = {'family': 'serif',
        'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 12}
plt.rc('font', **font)

from palettable.matplotlib import Viridis_7

cmap = Viridis_7.mpl_colormap

om_ex.plot(
    column='min_max_ex',
    ax=ax,
    cmap=cmap,
    legend=True,
#     legend_kwds={'label': 'Exposure'},
    scheme='NaturalBreaks',
#     k=7,
    legend_kwds={'loc': 'lower left',
                 'title': 'Exposure',
                 "fmt": "{:.3f}",
                 'title_fontsize': 14, 
                 'fontsize': 11, 
                 'shadow': True
                },               
#     missing_kwds={
#                 "color": "lightgrey",
#                 "edgecolor": "grey",
#                 "hatch": "////",
#                 "label": "Nan"
#                 },
#     prop={'family': 'Times New Roman', 'size': 16},
    edgecolor='white', #,np.array([0., 0., 0., 0.])
    linewidth=0.2
)

ax.axis('on')
ax.set_title('Transportation Energy Vulnerability in Omaha - Exposure',fontdict={'weight':'bold','size': 20},pad=20)
plt.tight_layout(pad=4.5)


ax.set_aspect('equal','box')
# fig.tight_layout()

fig.savefig('Omaha_exposure_map.png', facecolor='w', dpi=500)
# Out:
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# # Sensitivity

# %%
sensitivity = pd.read_csv("sensitivity_census.csv", dtype={"Geocode": str})
sensitivity.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      Geocode        X1      X2        X3  \
# 0             0           0  01001020100  0.166583  0.4378  0.113397
# 1             1           1  01001020200  0.166922  0.3305  0.582440
# 2             2           2  01001020300  0.172512  0.2927  0.260051
# 3             3           3  01001020400  0.046416  0.3711  0.070397
# 4             4           4  01001020500  0.149207  0.3735  0.192337
#
#          X4        X5        X6        X7  Sensitivity  z_score_sens  \
# 0  0.009533  0.717010  0.132464  0.188660     0.252207     -0.345779
# 1  0.004594  0.639612  0.144972  0.196018     0.295008      0.444644
# 2  0.066439  0.706872  0.160251  0.201882     0.265815     -0.094468
# 3  0.000000  0.751160  0.244714  0.167870     0.235951     -0.645974
# 4  0.030294  0.837958  0.138071  0.198282     0.274236      0.061032
#
#    min_max_sens
# 0      0.470402
# 1      0.550234
# 2      0.495784
# 3      0.440083
# 4      0.511489

# %%
om_sens = pd.merge(Omaha,sensitivity,left_on='GEOID',right_on="Geocode",how="left")
om_sens.head()
# Out:
#   STATEFP COUNTYFP TRACTCE AFFGEOID        GEOID  NAME  LSAD  ALAND  AWATER  \
# 0    None     None    None     None  31055006102  None  None    NaN     NaN
# 1    None     None    None     None  31055006400  None  None    NaN     NaN
# 2    None     None    None     None  31055006704  None  None    NaN     NaN
# 3    None     None    None     None  31055006905  None  None    NaN     NaN
# 4    None     None    None     None  31055007002  None  None    NaN     NaN
#
#   STATEFP_2  ...        X1      X2        X3        X4        X5        X6  \
# 0        31  ...  0.302421  0.4478  0.563885  0.042246  0.725657  0.105616
# 1        31  ...  0.120658  0.3388  0.087142  0.065204  0.805809  0.138533
# 2        31  ...  0.063222  0.2776  0.007295  0.005471  0.930091  0.312462
# 3        31  ...  0.056854  0.3478  0.021478  0.066330  0.743525  0.151611
# 4        31  ...  0.137893  0.3984  0.038886  0.123001  0.807226  0.180916
#
#          X7  Sensitivity z_score_sens  min_max_sens
# 0  0.317362     0.357855     1.605244      0.667452
# 1  0.202925     0.251296    -0.362596      0.468704
# 2  0.174468     0.252944    -0.332160      0.471778
# 3  0.214782     0.228911    -0.775975      0.426953
# 4  0.216216     0.271791     0.015886      0.506930
#
# [5 rows x 32 columns]

# %%
om_sens = gpd.GeoDataFrame(om_sens,crs = 4326)
# Out:
# C:\Users\jhawkins17\AppData\Local\Temp\ipykernel_18136\2499553030.py:1: FutureWarning: CRS mismatch between CRS of the passed geometries and 'crs'. Use 'GeoDataFrame.set_crs(crs, allow_override=True)' to overwrite CRS or 'GeoDataFrame.to_crs(crs)' to reproject geometries. CRS mismatch will raise an error in the future versions of GeoPandas.
#   om_sens = gpd.GeoDataFrame(om_sens,crs = 4326)

# %%
import numpy as np

fig, ax = plt.subplots(figsize=(12, 10),dpi=300)

font = {'family': 'serif',
        'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 12}
plt.rc('font', **font)

vmin = -0.541305087
vmax = 1.043413702

from palettable.matplotlib import Viridis_7

cmap = Viridis_7.mpl_colormap

om_sens.plot(
    column='min_max_sens',
    ax=ax,
    cmap=cmap,
    legend=True,
#     legend_kwds={'label': 'Exposure'},
#     scheme='NaturalBreaks',
#     k=7,
#     legend_kwds={'loc': 'lower left',
#                  'title': 'X7',
#                  'shadow': True
#                 },
#     missing_kwds={
#                  "color": "lightgrey",
#                  "edgecolor": "grey",
#                  "hatch": "////",
#                  "label": "Nan"
#                  },
#     edgecolor=np.array([0., 0., 0., 0.]),
    edgecolor = 'white',
    linewidth=0.2,
    vmin=vmin, vmax=vmax
)

ax.axis('on')
ax.set_title('Omaha Transportation Energy Vulnerability - Sensitivity',fontdict={'weight':'bold','size': 20},pad=20)
plt.tight_layout(pad=4.5)


ax.set_aspect('equal','box')
# fig.tight_layout()

fig.savefig('om_X7_test_map.png', facecolor='w', dpi=500)

# %% [markdown]
# # Adaptive Capacity - #N/A for NE so doesn't work

# %%
AC_tract_US = pd.read_csv("adaptive_capacity_census.csv",dtype={"GEO_ID":str})
AC_tract_US.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       GEO_ID  Weighted_D5be  Weighted_D4c  \
# 0             0           0  01001020100            NaN           NaN
# 1             1           1  01001020200            NaN           NaN
# 2             2           2  01001020300            NaN           NaN
# 3             3           3  01001020400            NaN           NaN
# 4             4           4  01001020500            NaN           NaN
#
#    Weighted_D4a  D5be_score  D4c_score  D4a_score  ac  min_max_ac
# 0           NaN         NaN        NaN        NaN NaN         NaN
# 1           NaN         NaN        NaN        NaN NaN         NaN
# 2           NaN         NaN        NaN        NaN NaN         NaN
# 3           NaN         NaN        NaN        NaN NaN         NaN
# 4           NaN         NaN        NaN        NaN NaN         NaN

# %%
AC_tract_US.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74102 entries, 0 to 74101
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   74102 non-null  int64
#  1   Unnamed: 0     74102 non-null  int64
#  2   GEO_ID         74102 non-null  object
#  3   Weighted_D5be  25521 non-null  float64
#  4   Weighted_D4c   28063 non-null  float64
#  5   Weighted_D4a   26565 non-null  float64
#  6   D5be_score     25521 non-null  float64
#  7   D4c_score      28063 non-null  float64
#  8   D4a_score      26565 non-null  float64
#  9   ac             25232 non-null  float64
#  10  min_max_ac     25231 non-null  float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 6.2+ MB

# %%
AC_tract_Omaha = pd.merge(Omaha,AC_tract_US,left_on="GEOID",right_on="GEO_ID",how="left")

# %%
AC_tract_Omaha.head()
# Out:
#   STATEFP COUNTYFP TRACTCE AFFGEOID        GEOID  NAME  LSAD  ALAND  AWATER  \
# 0    None     None    None     None  31055006102  None  None    NaN     NaN
# 1    None     None    None     None  31055006400  None  None    NaN     NaN
# 2    None     None    None     None  31055006704  None  None    NaN     NaN
# 3    None     None    None     None  31055006905  None  None    NaN     NaN
# 4    None     None    None     None  31055007002  None  None    NaN     NaN
#
#   STATEFP_2  ... Unnamed: 0       GEO_ID Weighted_D5be Weighted_D4c  \
# 0        31  ...      39317  31055006102           NaN          NaN
# 1        31  ...      39322  31055006400           NaN          NaN
# 2        31  ...      39332  31055006704           NaN          NaN
# 3        31  ...      39339  31055006905           NaN          NaN
# 4        31  ...      39342  31055007002           NaN          NaN
#
#   Weighted_D4a D5be_score  D4c_score  D4a_score  ac  min_max_ac
# 0          NaN        NaN        NaN        NaN NaN         NaN
# 1          NaN        NaN        NaN        NaN NaN         NaN
# 2          NaN        NaN        NaN        NaN NaN         NaN
# 3          NaN        NaN        NaN        NaN NaN         NaN
# 4          NaN        NaN        NaN        NaN NaN         NaN
#
# [5 rows x 30 columns]

# %%
ax.set_aspect('equal','box')
# fig.tight_layout()

fig.savefig('om_sensitivity_map.png', facecolor='w', dpi=500)

import numpy as np

fig, ax = plt.subplots(figsize=(12, 10),dpi=300)

from palettable.matplotlib import Viridis_7

cmap = Viridis_7.mpl_colormap

AC_tract_Omaha.plot(
    column='D5be_score',
    ax=ax,
    cmap=cmap,
    legend=True,
#     legend_kwds={'label': 'Exposure'},
    scheme='NaturalBreaks',
#     k=7,
    legend_kwds={'loc': 'lower left',
                 'title': '',
                 'shadow': True
                },
    missing_kwds={
                "color": "lightgrey",
                "edgecolor": "grey",
                "hatch": "////",
                "label": "Nan"
                },
#     edgecolor=np.array([0., 0., 0., 0.]),
    edgecolor = 'white',
    linewidth=0.2
)

ax.axis('off')
ax.set_title('Working-population within 45-minute transit commute', fontsize=15,pad=20)
plt.tight_layout(pad=4.5)


ax.set_aspect('equal','box')
# fig.tight_layout()

fig.savefig('D5be_normal_map.png', facecolor='w', dpi=500)
# Out:
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:1718: UserWarning: Warning: Not enough unique values in array to form k classes
#   Warn(ms, UserWarning)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:1719: UserWarning: Warning: setting k to 0
#   Warn("Warning: setting k to %d" % uvk, UserWarning)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:891: RuntimeWarning: invalid value encountered in double_scalars
#   gadf = 1 - self.adcm / adam
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 14>()
#      10 from palettable.matplotlib import Viridis_7
#      12 cmap = Viridis_7.mpl_colormap
# ---> 14 AC_tract_Omaha.plot(
#      15     column='D5be_score',
#      16     ax=ax,
#      17     cmap=cmap,
#      18     legend=True,
#      19 #     legend_kwds={'label': 'Exposure'},
#      20     scheme='NaturalBreaks',
#      21 #     k=7,
#      22     legend_kwds={'loc': 'lower left',
#      23                  'title': '',
#      24                  'shadow': True
#      25                 },
#      26     missing_kwds={
#      27                 "color": "lightgrey",
#      28                 "edgecolor": "grey",
#      29                 "hatch": "////",
#      30                 "label": "Nan"
#      31                 },
#      32 #     edgecolor=np.array([0., 0., 0., 0.]),
#      33     edgecolor = 'white',
#      34     linewidth=0.2
#      35 )
#      37 ax.axis('off')
#      38 ax.set_title('Working-population within 45-minute transit commute', fontsize=15,pad=20)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\geopandas\plotting.py:950, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     948 kind = kwargs.pop("kind", "geo")
#     949 if kind == "geo":
# --> 950     return plot_dataframe(data, *args, **kwargs)
#     951 if kind in self._pandas_kinds:
#     952     # Access pandas plots
#     953     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\geopandas\plotting.py:768, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     765 if legend_kwds is not None and "fmt" in legend_kwds:
#     766     fmt = legend_kwds.pop("fmt")
# --> 768 labels = binning.get_legend_classes(fmt)
#     769 if legend_kwds is not None:
#     770     show_interval = legend_kwds.pop("interval", False)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:978, in MapClassifier.get_legend_classes(self, fmt)
#     962 def get_legend_classes(self, fmt=FMT):
#     963     """
#     964     Format the strings for the classes on the legend
#     965
#    (...)
#     976            k strings with class interval definitions
#     977     """
# --> 978     return _get_mpl_labels(self, fmt)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:129, in _get_mpl_labels(mc, fmt)
#     112 def _get_mpl_labels(mc, fmt="{:.1f}"):
#     113     """
#     114     Helper method to format legend intervals for matplotlib (and geopandas)
#     115
#    (...)
#     127              k strings for class intervals
#     128     """
# --> 129     edges, max_width, lower_open = _format_intervals(mc, fmt)
#     130     k = len(edges) - 1
#     131     left = ["["]
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:97, in _format_intervals(mc, fmt)
#      67 def _format_intervals(mc, fmt="{:.0f}"):
#      68     """
#      69     Helper methods to format legend intervals
#      70
#    (...)
#      93     For some classifiers, it is possible that the upper bound of the first interval is less than the minimum value of the attribute that is being classified. In these cases `lower_open=True` and the lower bound of the interval is set to `np.NINF`.
#      94     """
# ---> 97     lowest = mc.y.min()
#      98     if hasattr(mc, 'lowest'):
#      99         if mc.lowest is not None:
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\_methods.py:44, in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
AC_tract_Omaha.D5be_score

# %%
import numpy as np

fig, ax = plt.subplots(figsize=(12, 10),dpi=300)

from palettable.matplotlib import Viridis_7

cmap = Viridis_7.mpl_colormap

AC_tract_Omaha.plot(
    column='D4c_score',
    ax=ax,
    cmap=cmap,
    legend=True,
#     legend_kwds={'label': 'Exposure'},
    scheme='NaturalBreaks',
#     k=7,
    legend_kwds={'loc': 'lower left',
                 'title': '',
                 'shadow': True
                },
    missing_kwds={
                "color": "lightgrey",
                "edgecolor": "grey",
                "hatch": "////",
                "label": "Nan"
                },
#     edgecolor=np.array([0., 0., 0., 0.]),
    edgecolor = 'white',
    linewidth=0.2
)

ax.axis('off')
ax.set_title("Aggregate frequency of transit service within 0.25 miles \n of block group boundary per hour during evening peak period", 
             fontsize=15,pad=20)
plt.tight_layout(pad=4.5)


ax.set_aspect('equal','box')
# fig.tight_layout()

fig.savefig('D4c_normal_map.png', facecolor='w', dpi=500)
# Out:
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:1718: UserWarning: Warning: Not enough unique values in array to form k classes
#   Warn(ms, UserWarning)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:1719: UserWarning: Warning: setting k to 0
#   Warn("Warning: setting k to %d" % uvk, UserWarning)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:891: RuntimeWarning: invalid value encountered in double_scalars
#   gadf = 1 - self.adcm / adam
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 9>()
#       5 from palettable.matplotlib import Viridis_7
#       7 cmap = Viridis_7.mpl_colormap
# ----> 9 AC_tract_Omaha.plot(
#      10     column='D4c_score',
#      11     ax=ax,
#      12     cmap=cmap,
#      13     legend=True,
#      14 #     legend_kwds={'label': 'Exposure'},
#      15     scheme='NaturalBreaks',
#      16 #     k=7,
#      17     legend_kwds={'loc': 'lower left',
#      18                  'title': '',
#      19                  'shadow': True
#      20                 },
#      21     missing_kwds={
#      22                 "color": "lightgrey",
#      23                 "edgecolor": "grey",
#      24                 "hatch": "////",
#      25                 "label": "Nan"
#      26                 },
#      27 #     edgecolor=np.array([0., 0., 0., 0.]),
#      28     edgecolor = 'white',
#      29     linewidth=0.2
#      30 )
#      32 ax.axis('off')
#      33 ax.set_title("Aggregate frequency of transit service within 0.25 miles \n of block group boundary per hour during evening peak period",
#      34              fontsize=15,pad=20)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\geopandas\plotting.py:950, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     948 kind = kwargs.pop("kind", "geo")
#     949 if kind == "geo":
# --> 950     return plot_dataframe(data, *args, **kwargs)
#     951 if kind in self._pandas_kinds:
#     952     # Access pandas plots
#     953     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\geopandas\plotting.py:768, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     765 if legend_kwds is not None and "fmt" in legend_kwds:
#     766     fmt = legend_kwds.pop("fmt")
# --> 768 labels = binning.get_legend_classes(fmt)
#     769 if legend_kwds is not None:
#     770     show_interval = legend_kwds.pop("interval", False)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:978, in MapClassifier.get_legend_classes(self, fmt)
#     962 def get_legend_classes(self, fmt=FMT):
#     963     """
#     964     Format the strings for the classes on the legend
#     965
#    (...)
#     976            k strings with class interval definitions
#     977     """
# --> 978     return _get_mpl_labels(self, fmt)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:129, in _get_mpl_labels(mc, fmt)
#     112 def _get_mpl_labels(mc, fmt="{:.1f}"):
#     113     """
#     114     Helper method to format legend intervals for matplotlib (and geopandas)
#     115
#    (...)
#     127              k strings for class intervals
#     128     """
# --> 129     edges, max_width, lower_open = _format_intervals(mc, fmt)
#     130     k = len(edges) - 1
#     131     left = ["["]
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:97, in _format_intervals(mc, fmt)
#      67 def _format_intervals(mc, fmt="{:.0f}"):
#      68     """
#      69     Helper methods to format legend intervals
#      70
#    (...)
#      93     For some classifiers, it is possible that the upper bound of the first interval is less than the minimum value of the attribute that is being classified. In these cases `lower_open=True` and the lower bound of the interval is set to `np.NINF`.
#      94     """
# ---> 97     lowest = mc.y.min()
#      98     if hasattr(mc, 'lowest'):
#      99         if mc.lowest is not None:
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\_methods.py:44, in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
import numpy as np

fig, ax = plt.subplots(figsize=(12, 10),dpi=300)

from palettable.matplotlib import Viridis_7

cmap = Viridis_7.mpl_colormap

AC_tract_Omaha.plot(
    column='D4a_score',
    ax=ax,
    cmap=cmap,
    legend=True,
#     legend_kwds={'label': 'Exposure'},
    scheme='NaturalBreaks',
#     k=7,
    legend_kwds={'loc': 'lower left',
                 'title': '',
                 'shadow': True
                },
    missing_kwds={
                  "color": "lightgrey",
                  "edgecolor": "grey",
                  "hatch": "////",
                  "label": "Nan"
                  },
#     edgecolor=np.array([0., 0., 0., 0.]),
    edgecolor = 'white',
    linewidth=0.2
)

ax.axis('off')
ax.set_title('Distance from population weighted centroid to nearest transit stop', 
             fontsize=15,pad=20)
plt.tight_layout(pad=4.5)


ax.set_aspect('equal','box')
# fig.tight_layout()

fig.savefig('D4a_normal_map.png', facecolor='w', dpi=500)
# Out:
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:1718: UserWarning: Warning: Not enough unique values in array to form k classes
#   Warn(ms, UserWarning)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:1719: UserWarning: Warning: setting k to 0
#   Warn("Warning: setting k to %d" % uvk, UserWarning)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:891: RuntimeWarning: invalid value encountered in double_scalars
#   gadf = 1 - self.adcm / adam
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 9>()
#       5 from palettable.matplotlib import Viridis_7
#       7 cmap = Viridis_7.mpl_colormap
# ----> 9 AC_tract_Omaha.plot(
#      10     column='D4a_score',
#      11     ax=ax,
#      12     cmap=cmap,
#      13     legend=True,
#      14 #     legend_kwds={'label': 'Exposure'},
#      15     scheme='NaturalBreaks',
#      16 #     k=7,
#      17     legend_kwds={'loc': 'lower left',
#      18                  'title': '',
#      19                  'shadow': True
#      20                 },
#      21     missing_kwds={
#      22                   "color": "lightgrey",
#      23                   "edgecolor": "grey",
#      24                   "hatch": "////",
#      25                   "label": "Nan"
#      26                   },
#      27 #     edgecolor=np.array([0., 0., 0., 0.]),
#      28     edgecolor = 'white',
#      29     linewidth=0.2
#      30 )
#      32 ax.axis('off')
#      33 ax.set_title('Distance from population weighted centroid to nearest transit stop',
#      34              fontsize=15,pad=20)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\geopandas\plotting.py:950, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     948 kind = kwargs.pop("kind", "geo")
#     949 if kind == "geo":
# --> 950     return plot_dataframe(data, *args, **kwargs)
#     951 if kind in self._pandas_kinds:
#     952     # Access pandas plots
#     953     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\geopandas\plotting.py:768, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     765 if legend_kwds is not None and "fmt" in legend_kwds:
#     766     fmt = legend_kwds.pop("fmt")
# --> 768 labels = binning.get_legend_classes(fmt)
#     769 if legend_kwds is not None:
#     770     show_interval = legend_kwds.pop("interval", False)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:978, in MapClassifier.get_legend_classes(self, fmt)
#     962 def get_legend_classes(self, fmt=FMT):
#     963     """
#     964     Format the strings for the classes on the legend
#     965
#    (...)
#     976            k strings with class interval definitions
#     977     """
# --> 978     return _get_mpl_labels(self, fmt)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:129, in _get_mpl_labels(mc, fmt)
#     112 def _get_mpl_labels(mc, fmt="{:.1f}"):
#     113     """
#     114     Helper method to format legend intervals for matplotlib (and geopandas)
#     115
#    (...)
#     127              k strings for class intervals
#     128     """
# --> 129     edges, max_width, lower_open = _format_intervals(mc, fmt)
#     130     k = len(edges) - 1
#     131     left = ["["]
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:97, in _format_intervals(mc, fmt)
#      67 def _format_intervals(mc, fmt="{:.0f}"):
#      68     """
#      69     Helper methods to format legend intervals
#      70
#    (...)
#      93     For some classifiers, it is possible that the upper bound of the first interval is less than the minimum value of the attribute that is being classified. In these cases `lower_open=True` and the lower bound of the interval is set to `np.NINF`.
#      94     """
# ---> 97     lowest = mc.y.min()
#      98     if hasattr(mc, 'lowest'):
#      99         if mc.lowest is not None:
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\_methods.py:44, in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
import numpy as np

fig, ax = plt.subplots(figsize=(12, 10),dpi=300)

font = {'family': 'serif',
        'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 12}
plt.rc('font', **font)

from palettable.matplotlib import Viridis_7

cmap = Viridis_7.mpl_colormap

AC_tract_Omaha.plot(
    column='min_max_ac',
    ax=ax,
    cmap=cmap,
    legend=True,
#     legend_kwds={'label': 'Exposure'},
    scheme='NaturalBreaks',
#     k=7,
    legend_kwds={'loc': 'lower left',
                 'title': 'Adaptive Capacity',
                 'shadow': True
                },
    missing_kwds={
                 "color": "lightgrey",
                 "edgecolor": "grey",
                 "hatch": "////",
                 "label": "Nan"
                 },
#     edgecolor=np.array([0., 0., 0., 0.]),
    edgecolor = 'white',
    linewidth=0.2
)

ax.axis('on')
ax.set_title('Chicago City Transportation Energy Vulnerability - Adaptive Capacity',fontdict={'weight':'bold','size': 20},pad=20)
plt.tight_layout(pad=4.5)

ax.set_aspect('equal','box')
fig.tight_layout()

fig.savefig('Chicago_AC_map.png', facecolor='w', dpi=500)
# Out:
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:1718: UserWarning: Warning: Not enough unique values in array to form k classes
#   Warn(ms, UserWarning)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:1719: UserWarning: Warning: setting k to 0
#   Warn("Warning: setting k to %d" % uvk, UserWarning)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:891: RuntimeWarning: invalid value encountered in double_scalars
#   gadf = 1 - self.adcm / adam
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 15>()
#      11 from palettable.matplotlib import Viridis_7
#      13 cmap = Viridis_7.mpl_colormap
# ---> 15 AC_tract_Omaha.plot(
#      16     column='min_max_ac',
#      17     ax=ax,
#      18     cmap=cmap,
#      19     legend=True,
#      20 #     legend_kwds={'label': 'Exposure'},
#      21     scheme='NaturalBreaks',
#      22 #     k=7,
#      23     legend_kwds={'loc': 'lower left',
#      24                  'title': 'Adaptive Capacity',
#      25                  'shadow': True
#      26                 },
#      27     missing_kwds={
#      28                  "color": "lightgrey",
#      29                  "edgecolor": "grey",
#      30                  "hatch": "////",
#      31                  "label": "Nan"
#      32                  },
#      33 #     edgecolor=np.array([0., 0., 0., 0.]),
#      34     edgecolor = 'white',
#      35     linewidth=0.2
#      36 )
#      38 ax.axis('on')
#      39 ax.set_title('Chicago City Transportation Energy Vulnerability - Adaptive Capacity',fontdict={'weight':'bold','size': 20},pad=20)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\geopandas\plotting.py:950, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     948 kind = kwargs.pop("kind", "geo")
#     949 if kind == "geo":
# --> 950     return plot_dataframe(data, *args, **kwargs)
#     951 if kind in self._pandas_kinds:
#     952     # Access pandas plots
#     953     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\geopandas\plotting.py:768, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     765 if legend_kwds is not None and "fmt" in legend_kwds:
#     766     fmt = legend_kwds.pop("fmt")
# --> 768 labels = binning.get_legend_classes(fmt)
#     769 if legend_kwds is not None:
#     770     show_interval = legend_kwds.pop("interval", False)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:978, in MapClassifier.get_legend_classes(self, fmt)
#     962 def get_legend_classes(self, fmt=FMT):
#     963     """
#     964     Format the strings for the classes on the legend
#     965
#    (...)
#     976            k strings with class interval definitions
#     977     """
# --> 978     return _get_mpl_labels(self, fmt)
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:129, in _get_mpl_labels(mc, fmt)
#     112 def _get_mpl_labels(mc, fmt="{:.1f}"):
#     113     """
#     114     Helper method to format legend intervals for matplotlib (and geopandas)
#     115
#    (...)
#     127              k strings for class intervals
#     128     """
# --> 129     edges, max_width, lower_open = _format_intervals(mc, fmt)
#     130     k = len(edges) - 1
#     131     left = ["["]
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\mapclassify\classifiers.py:97, in _format_intervals(mc, fmt)
#      67 def _format_intervals(mc, fmt="{:.0f}"):
#      68     """
#      69     Helper methods to format legend intervals
#      70
#    (...)
#      93     For some classifiers, it is possible that the upper bound of the first interval is less than the minimum value of the attribute that is being classified. In these cases `lower_open=True` and the lower bound of the interval is set to `np.NINF`.
#      94     """
# ---> 97     lowest = mc.y.min()
#      98     if hasattr(mc, 'lowest'):
#      99         if mc.lowest is not None:
#
# File ~\Anaconda3\envs\my_geo_env\lib\site-packages\numpy\core\_methods.py:44, in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# # Vulnerability Score

# %%
vc = pd.read_csv('Vulnerability Score.csv',dtype={'GEOID':str})
vc.head()
# Out:
#    Unnamed: 0        GEOID   min-max  min_max_sens  AC_score  vul_score_mulpi  \
# 0           0  01117030317  0.057365      0.483589  0.000000         0.027741
# 1           1  01119011500  0.197691      0.693445  0.000000         0.137088
# 2           2  01121010900  0.116124      0.552217  0.000000         0.064125
# 3           3  01125010102  0.057489      0.419161  0.000000         0.024097
# 4           4  01089000701  0.074292      0.708373  0.215956         0.036583
#
#    vul_mulpi_1/3  vul_score_add  vul_add_1/3
# 0       0.003082       0.540954     0.180318
# 1       0.015232       0.891136     0.297045
# 2       0.007125       0.668341     0.222780
# 3       0.002677       0.476650     0.158883
# 4       0.004065       0.566710     0.188903

# %%
om_vc = pd.merge(Omaha,vc,left_on='GEOID',right_on="GEOID",how="left")
om_vc.head()
# Out:
#   STATEFP COUNTYFP TRACTCE AFFGEOID        GEOID  NAME  LSAD  ALAND  AWATER  \
# 0    None     None    None     None  31055006102  None  None    NaN     NaN
# 1    None     None    None     None  31055006400  None  None    NaN     NaN
# 2    None     None    None     None  31055006704  None  None    NaN     NaN
# 3    None     None    None     None  31055006905  None  None    NaN     NaN
# 4    None     None    None     None  31055007002  None  None    NaN     NaN
#
#   STATEFP_2  ... AWATER_2                                           geometry  \
# 0        31  ...      0.0  POLYGON ((-95.97578 41.31006, -95.97578 41.311...
# 1        31  ...      0.0  POLYGON ((-96.02387 41.26328, -96.02387 41.266...
# 2        31  ...  99304.0  POLYGON ((-96.08508 41.24870, -96.08356 41.250...
# 3        31  ...  14361.0  POLYGON ((-96.06232 41.22337, -96.05886 41.223...
# 4        31  ...      0.0  POLYGON ((-96.00472 41.23060, -95.99513 41.230...
#
#   Unnamed: 0   min-max min_max_sens AC_score  vul_score_mulpi  vul_mulpi_1/3  \
# 0      39207  0.121541     0.667452      0.0         0.081123       0.009014
# 1      39208  0.087512     0.468704      0.0         0.041017       0.004557
# 2      39209  0.047240     0.471778      0.0         0.022287       0.002476
# 3      39210  0.067912     0.426953      0.0         0.028995       0.003222
# 4      39211  0.075770     0.506930      0.0         0.038410       0.004268
#
#   vul_score_add  vul_add_1/3
# 0      0.788994     0.262998
# 1      0.556215     0.185405
# 2      0.519018     0.173006
# 3      0.494865     0.164955
# 4      0.582700     0.194233
#
# [5 rows x 27 columns]

# %%
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10),dpi=300)

font = {'family': 'serif',
        'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 12}
plt.rc('font', **font)

from palettable.matplotlib import Viridis_7

cmap = Viridis_7.mpl_colormap

om_vc.plot(
    column='vul_score_mulpi',
    ax=ax,
    cmap=cmap,
    legend=True,
#     legend_kwds={'label': 'Exposure'},
    scheme='NaturalBreaks',
#     scheme='UserDefined',
#     classification_kwds={
#                         'bins': [0, 0.05, 0.1, 0.15, 0.2, 0.25]
#                         },
#     k=7,
    legend_kwds={'loc': 'center left',
                 'title': 'Vulnerability Score',
                 "fmt": "{:.3f}",
                 'title_fontsize': 14, 
                 'fontsize': 14, 
                 'shadow': True},
#     missing_kwds={
#                  "color": "lightgrey",
#                  "edgecolor": "grey",
#                  "hatch": "////",
#                  "label": "Nan"
#                  },
#     edgecolor=np.array([0., 0., 0., 0.]),
    edgecolor = 'white',
    linewidth=0.2,
#     vmin=vmin, vmax=vmax
)

# ax.axis('on')
plt.xticks([])
plt.yticks([])
ax.set_title('Multiplicative Transportation Energy Vulnerability in Omaha', fontdict={'weight':'bold','size': 20},pad=20)
plt.tight_layout(pad=4.5)


ax.set_aspect('equal','box')
# fig.tight_layout()

fig.savefig('Omaha_vulnerability_multip.png', facecolor='w', dpi=500)
# Out:
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10),dpi=300)

font = {'family': 'serif',
        'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 12}
plt.rc('font', **font)

from palettable.matplotlib import Viridis_7

cmap = Viridis_7.mpl_colormap

om_vc.plot(
    column='vul_score_add',
    ax=ax,
    cmap=cmap,
    legend=True,
#     legend_kwds={'label': 'Exposure'},
    scheme='NaturalBreaks',
#     scheme='UserDefined',
#     classification_kwds={
#                         'bins': [0, 0.05, 0.1, 0.15, 0.2, 0.25]
#                         },
#     k=7,
    legend_kwds={'loc': 'center left',
                 'title': 'Vulnerability Score',
                 "fmt": "{:.3f}",
                 
                 'title_fontsize': 14, 
                 'fontsize': 14, 
                 'shadow': True},
#     missing_kwds={
#                  "color": "lightgrey",
#                  "edgecolor": "grey",
#                  "hatch": "////",
#                  "label": "Nan"
#                  },
#     edgecolor=np.array([0., 0., 0., 0.]),
    edgecolor = 'white',
    linewidth=0.2,
#     vmin=vmin, vmax=vmax
)

# ax.axis('on')
plt.xticks([])
plt.yticks([])
ax.set_title('Additive Transportation Energy Vulnerability in Omaha', fontdict={'weight':'bold','size': 20},pad=20)
plt.tight_layout(pad=4.5)


ax.set_aspect('equal','box')
# fig.tight_layout()

fig.savefig('Omaha_vulnerability_add.png', facecolor='w', dpi=500)
# Out:
# C:\Users\jhawkins17\Anaconda3\envs\my_geo_env\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
